# %%
import pandas as pd
df=pd.read_csv('/content/Groceries_dataset.csv')
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(759)

# %%
df.drop_duplicates()
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38006 rows x 3 columns]

# %%
df['itemDescription'].unique()
# Out:
# array(['tropical fruit', 'whole milk', 'pip fruit', 'other vegetables',
#        'rolls/buns', 'pot plants', 'citrus fruit', 'beef', 'frankfurter',
#        'chicken', 'butter', 'fruit/vegetable juice',
#        'packaged fruit/vegetables', 'chocolate', 'specialty bar',
#        'butter milk', 'bottled water', 'yogurt', 'sausage', 'brown bread',
#        'hamburger meat', 'root vegetables', 'pork', 'pastry',
#        'canned beer', 'berries', 'coffee', 'misc. beverages', 'ham',
#        'turkey', 'curd cheese', 'red/blush wine',
#        'frozen potato products', 'flour', 'sugar', 'frozen meals',
#        'herbs', 'soda', 'detergent', 'grapes', 'processed cheese', 'fish',
#        'sparkling wine', 'newspapers', 'curd', 'pasta', 'popcorn',
#        'finished products', 'beverages', 'bottled beer', 'dessert',
#        'dog food', 'specialty chocolate', 'condensed milk', 'cleaner',
#        'white wine', 'meat', 'ice cream', 'hard cheese', 'cream cheese ',
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
#import plotly express as px
df['Date']=pd.to_datetime(df['Date'],infer_datetime_format=True)
df['Year']=df['Date'].dt.year
plt.figure(figsize=(10,7))
sns.countplot(x='Year',data=df,hue='Year')
plt.title("When were the purchase made?")
plt.xlabel('Year')
plt.legend(title='Year')
plt.show()

# %%
df_unstack = (
    df.groupby(['Member_number', 'itemDescription'])['itemDescription'].count().unstack().fillna(0))
df_unstack
# Out:
# itemDescription  Instant food products  UHT-milk  abrasive cleaner  \
# Member_number
# 1000                               0.0       0.0               0.0
# 1001                               0.0       0.0               0.0
# 1002                               0.0       0.0               0.0
# 1003                               0.0       0.0               0.0
# 1004                               0.0       0.0               0.0
# ...                                ...       ...               ...
# 4996                               0.0       0.0               0.0
# 4997                               0.0       0.0               0.0
# 4998                               0.0       0.0               0.0
# 4999                               0.0       0.0               0.0
# 5000                               0.0       0.0               0.0
#
# itemDescription  artif. sweetener  baby cosmetics  bags  baking powder  \
# Member_number
# ...

# %%
def encode(x):
  if x>0:
    return 1
  if x<=0:
    return 0

df_set=df_unstack.applymap(encode)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import warnings
warnings.filterwarnings('ignore')
df_set_freq=apriori(df_set,min_support=0.07,use_colnames=True)
df_set_freq.head()
# Out:
#     support         itemsets
# 0  0.078502       (UHT-milk)
# 1  0.119548           (beef)
# 2  0.079785        (berries)
# 3  0.158799   (bottled beer)
# 4  0.213699  (bottled water)

# %%
from mlxtend.frequent_patterns import association_rules
df_rules=association_rules(df_set_freq,metric='lift',min_threshold=1)
df_rules.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0        (whole milk)      (bottled beer)            0.458184
# 1      (bottled beer)        (whole milk)            0.158799
# 2  (other vegetables)     (bottled water)            0.376603
# 3     (bottled water)  (other vegetables)            0.213699
# 4        (rolls/buns)     (bottled water)            0.349666
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.158799  0.085428    0.186450  1.174124               1.0
# 1            0.458184  0.085428    0.537964  1.174124               1.0
# 2            0.213699  0.093894    0.249319  1.166680               1.0
# 3            0.376603  0.093894    0.439376  1.166680               1.0
# 4            0.213699  0.079271    0.226706  1.060863               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.012669    1.033988       0.273711  0.160714   0.032871    0.362207
# ...

# %%
def get_recommendations(product,rules,num_recommendations=5):
#product="bottled beer"
#rules=df_rules
  recommendations=[]
  for idk,row in rules.iterrows():
    if product in row['antecedents']:
      recommended_items=next(iter(row['consequents']))
      recommendations.append((recommended_items,row['lift']))
      recommendations.sort(key=lambda x:x[1],reverse=True)
#print(recommendations)
  return recommendations[:num_recommendations]

# %%
df
# Out:
#        Member_number       Date        itemDescription  Year
# 0               1808 2015-07-21         tropical fruit  2015
# 1               2552 2015-01-05             whole milk  2015
# 2               2300 2015-09-19              pip fruit  2015
# 3               1187 2015-12-12       other vegetables  2015
# 4               3037 2015-02-01             whole milk  2015
# ...              ...        ...                    ...   ...
# 38760           4471 2014-10-08          sliced cheese  2014
# 38761           2022 2014-02-23                  candy  2014
# 38762           1097 2014-04-16               cake bar  2014
# 38763           1510 2014-12-03  fruit/vegetable juice  2014
# 38764           1521 2014-12-26               cat food  2014
#
# [38765 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def countplotnew(df, column_name='Year'):
    sns.countplot(data=df, x=column_name)
     #sns.histplot(data=df, x=column_name, bins=10, kde=True, color='green')

countplotnew(df)

# %%
product_to_recommend="tropical fruit"
recommendations=get_recommendations(product_to_recommend,df_rules)
print(recommendations,"\n")
print(f"Recommendations for'{product_to_recommend}:':")
for item,lift in recommendations:
  print(f"{item}(lift:{lift:.2f})")
# Out:
# [('yogurt', 1.1443792152526842), ('soda', 1.1169736678997022), ('whole milk', 1.0876717683458241), ('rolls/buns', 1.0799062248075815), ('other vegetables', 1.037641660958853)]
#
# Recommendations for'tropical fruit:':
# yogurt(lift:1.14)
# soda(lift:1.12)
# whole milk(lift:1.09)
# rolls/buns(lift:1.08)
# other vegetables(lift:1.04)
